# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import os

# %%
df2 =pd.read_excel("INDOCE 10 03 26  SIREC.xlsx", sheet_name="INDOCE")

# %%
df2.columns
# Out:
# Index(['Clave Unidad', 'NSS', 'Agregado', 'COMPLETO', 'Nombre', 'Especialidad',
#        'Dx CIE', 'Fecha Solicitud', 'Fecha Cita', 'Consultorio'],
#       dtype='object')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3800 entries, 0 to 3799
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Clave Unidad     3800 non-null   object
#  1   NSS              3800 non-null   int64
#  2   Agregado         3800 non-null   object
#  3   COMPLETO         3800 non-null   object
#  4   Nombre           3800 non-null   object
#  5   Especialidad     3800 non-null   object
#  6   Dx CIE           3715 non-null   object
#  7   Fecha Solicitud  3800 non-null   object
#  8   Fecha Cita       3800 non-null   object
#  9   Consultorio      3800 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 297.0+ KB
