# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import os

# %%
df2 =pd.read_excel("INDOCE 10 03 26  SIREC.xlsx", sheet_name="INDOCE")
df = pd.read_excel("DF72F2A6-export.xlsx", sheet_name="ListadoCitasComprometidas")
df.columns = [
        "CVE_DEL", "SOLICITO", "NOMSOLI", "FECHASOLICITUD", "HOSPITAL", "NOMHOSP", "SERVICIO", 
        "nomServ", "FECHACITA", "CONSULTORIO", "TURNO", "HORACITA", "NSS", "AGREGADO", 
        "NOMBRE", "PATERNO", "MATERNO", "DiasHabilRefer_Cita", "TEL", "CEL", "MAIL"
    ]
df.dropna(subset=['NOMSOLI', 'NOMHOSP'], inplace=True)
df = df.iloc[1:].copy() # Eliminar la fila extra de encabezado si aplica

# %%
df2.columns
# Out:
# Index(['Clave Unidad', 'NSS', 'Agregado', 'COMPLETO', 'Nombre', 'Especialidad',
#        'Dx CIE', 'Fecha Solicitud', 'Fecha Cita', 'Consultorio'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['CVE_DEL', 'SOLICITO', 'NOMSOLI', 'FECHASOLICITUD', 'HOSPITAL',
#        'NOMHOSP', 'SERVICIO', 'nomServ', 'FECHACITA', 'CONSULTORIO', 'TURNO',
#        'HORACITA', 'NSS', 'AGREGADO', 'NOMBRE', 'PATERNO', 'MATERNO',
#        'DiasHabilRefer_Cita', 'TEL', 'CEL', 'MAIL'],
#       dtype='object')
